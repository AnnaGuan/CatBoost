# %%
from sklearn.model_selection import KFold,LeaveOneOut,LeavePOut,ShuffleSplit 
from feat_selection import *
from model_new import *
from data_config import *
from data_process import *
from catboost import CatBoostRegressor, Pool
import shap
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import f1_score
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import h5py

# %%
sys.argv=['CatBOOST_2022',1]

# %% [markdown]
# ####     method=['CatBOOST_2022','deepsynergy_preuer_2018','XGBOOST_janizek_2018']

# %% [markdown]
# ####      i=[1,2,3,4,5]

# %%
available_feat_type_list = {'NCI_60':['met','mut','cop','exp']}
available_cancer_specific_cell_list = {'NCI_60':{'TNBC':['MDA-MB-231','MDA-MB-435','BT-549','HS 578T']}}

SYNERGY_THRES = 10
BATCH_SIZE = 256
N_EPOCHS = 200
PATIENCE = 30
  
    
    
def prepare_data():
    synergy_data = input_synergy_data(config['synergy_data'])  # 导入数据
    cell_data_dicts = input_cellline_data(config['cell_data'])
    drug_data_dict = input_drug_data()

    drug_list = synergy_data['drug1'].unique().tolist()  # 提取所有药物名称的列表
    cell_list = synergy_data['cell'].unique().tolist()  # 提取所有细胞名称的列表

    drug_list = filter_drug(drug_list, config['drug_feat_filter'])  # 过滤药物特征
    cell_list = filter_cell(cell_list, config['cell_list'],
                            available_cancer_specific_cell_list[config['cell_data']])  # 过滤细胞
    synergy_data = synergy_data[
        (synergy_data['drug1'].isin(drug_list)) & synergy_data['drug2'].isin(drug_list) & synergy_data['cell'].isin(
            cell_list)]

    # 选取包含共同的药物和细胞的数据
    cell_feats, selected_cells = filter_cell_features(cell_data_dicts, cell_list, config['cell_feats'],
                                                      config['cell_feat_filter'], config['cell_integrate'])
    # 过滤细胞特征
    synergy_data = synergy_data[synergy_data['cell'].isin(selected_cells)]

    # 选取包含共同细胞的数据

    print("\n")
    print("number of drugs:", len(drug_list))
    print("number of cells:", len(selected_cells))
    print("number of data:", synergy_data.shape)
    print("\n")

    if config['cell_integrate'] == True:  # 构建细胞矩阵
        X_cell = np.zeros((synergy_data.shape[0], cell_feats.shape[0]))  # 构建矩阵
        for i in tqdm(range(synergy_data.shape[0])):
            row = synergy_data.iloc[i]
            X_cell[i, :] = cell_feats[row['cell']].values  # 根据细胞，给矩阵赋值
    else:
        X_cell = {}
        for feat_type in config['cell_feats']:  # cell_feats有几个特征类型
            print(feat_type, cell_feats[feat_type].shape[0])  # 此时cell_feats是一个字典
            temp_cell = np.zeros((synergy_data.shape[0], cell_feats[feat_type].shape[0]))
            for i in tqdm(range(synergy_data.shape[0])):
                row = synergy_data.iloc[i]
                temp_cell[i, :] = cell_feats[feat_type][row['cell']].values
            X_cell[feat_type] = temp_cell

    if config['cell_integrate'] == True:
        print("cell features: ", X_cell.shape)
    else:
        print("cell features:", list(X_cell.keys()))

    print("\ngenerating drug feats...")
    drug_matrix_dict = {}
    for feat_type in config['drug_feats']:  # 构建药物矩阵
        if feat_type != 'monetherapy':  # 单药治疗
            dim = drug_data_dict[feat_type].shape[0]
            temp_X_1 = np.zeros((synergy_data.shape[0], dim))
            temp_X_2 = np.zeros((synergy_data.shape[0], dim))
            for i in tqdm(range(synergy_data.shape[0])):
                row = synergy_data.iloc[i]
                temp_X_1[i, :] = drug_data_dict[feat_type][int(row['drug1'])]
                temp_X_2[i, :] = drug_data_dict[feat_type][int(row['drug2'])]
        else:
            dim = 3
            temp_X_1 = np.zeros((synergy_data.shape[0], dim))
            temp_X_2 = np.zeros((synergy_data.shape[0], dim))
            for i in tqdm(range(synergy_data.shape[0])):
                row = synergy_data.iloc[i]
                temp_X_1[i, :] = drug_data_dict[feat_type].loc[row['cell'], int(row['drug1'])]
                temp_X_2[i, :] = drug_data_dict[feat_type].loc[row['cell'], int(row['drug2'])]
        drug_matrix_dict[feat_type + '_1'] = temp_X_1
        drug_matrix_dict[feat_type + '_2'] = temp_X_2

    X_drug_temp = {}  # 接下来是药物特征矩阵是否独立
    if config['drug_indep'] == False:
        for feat_type in config['drug_feats']:
            if feat_type != 'monetherapy':
                temp_X = drug_matrix_dict[feat_type + '_1'] + drug_matrix_dict[feat_type + '_2']  # 矩阵相加
                X_drug_temp[feat_type] = temp_X
            else:  # 单药治疗，所以要分开
                X_drug_temp[feat_type + '_1'] = drug_matrix_dict[feat_type + '_1']
                X_drug_temp[feat_type + '_2'] = drug_matrix_dict[feat_type + '_2']
    else:
        X_drug_temp = drug_matrix_dict

    if config['drug_integrate'] == False:  # 药物特征是否需要合并
        X_drug = X_drug_temp
    else:
        X_drug = np.concatenate(list(X_drug_temp.values()), axis=1)

    if config['drug_integrate'] == True:
        print("drug features: ", X_drug.shape)
    else:
        print("drug features")
        print(list(X_drug.keys()))
        for key, value in X_drug.items():
            print(key, value.shape)
    
    Y = (synergy_data['score'] > SYNERGY_THRES).astype(int).values

    return X_cell, X_drug, Y


def idx(i):
    train_idx = np.load(r'..\idx\train_idx_%s.npy' % (i))
    test_idx = np.load(r'..\idx\test_idx_%s.npy' % (i))
    return train_idx, test_idx


def training(X_cell, X_drug, Y, train_idx, test_idx):
    X = np.concatenate([X_cell, X_drug], axis=1)
    X_train, Y_train = X[train_idx], Y[train_idx]
    X_test, Y_test = X[test_idx], Y[test_idx]
    
    model = get_model(config['model_name'])

    if config['model_name'] ==  'NN':
        model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'])
        callbacks = [EarlyStopping(monitor='val_loss', patience=PATIENCE),
                         ModelCheckpoint(filepath='best_model_%s.h5' % config['model_name'], monitor='val_loss',
                                         save_best_only=True)]
        _ = model.fit(X_train, Y_train,
                              batch_size=BATCH_SIZE,
                              epochs=N_EPOCHS,
                              verbose=1,
                              validation_split=0.1,
                              callbacks=callbacks)
       
    elif config['model_name'] == 'CatBoost':
        
        model.fit(X_train, Y_train, verbose=3)
    else:
        
        model.fit(X_train, Y_train)

    return model, X_test, Y_test


def evaluate(model, X_test, Y_test):
    if config['model_name'] == 'NN':
        pred = model.predict(X_test)
        pred=pred[:,0]
    elif config['model_name'] == 'CatBoost':
        pred = model.predict(X_test)
    else:
        pred = model.predict_proba(X_test)[:, 1]

    auc = roc_auc_score(Y_test, pred)
    ap = average_precision_score(Y_test, pred)
    RMSE = np.sqrt(mean_squared_error(Y_test, pred))
    RPearson = np.corrcoef(np.array(Y_test), np.array(pred))[0,1]
   

    val_results = {'AUC': auc, 'AUPR': ap, 'RMSE': RMSE,'RPearson':RPearson, 'Y_test': Y_test.tolist(), 'Y_pred': pred.tolist()}
    #val_results = {'RMSE': RMSE,'RPearson':RPearson, 'Y_test': Y_test.tolist(), 'Y_pred': pred.tolist()}

    return val_results


def main(method, i):
    X_cell, X_drug, Y = prepare_data()
    print("data loaded")

    train_idx, test_idx = idx(i)

    model, X_test, Y_test = training(X_cell, X_drug, Y, train_idx, test_idx)
    print("training finished")
    val_results = evaluate(model, X_test, Y_test)

    # save results
    rand_num = random.randint(1, 1000000)
    with open(r"..\results\%s_%s.json" % (method, str(rand_num)), "w") as f:
        json.dump(val_results, f)


if __name__ == "__main__":
    method = sys.argv[0]
    i = sys.argv[1]
    # this is a global variable
    config = method_config_dict[method]
    print(method, config, i)
    main(method,i)
# Out:
# CatBOOST_2022 {'synergy_data': 'NCI_ALMANAC', 'cell_data': 'NCI_60', 'cell_list': 'all', 'drug_feats': ['morgan_fingerprint', 'drug_target', 'monetherapy'], 'cell_feats': ['exp'], 'cell_feat_filter': 'cancer', 'drug_feat_filter': 'target', 'model_name': 'CatBoost', 'cell_integrate': True, 'drug_integrate': True, 'drug_indep': False} 1
#
#
# number of drugs: 68
# number of cells: 59
# number of data: (130182, 4)
# 100%|███████████████████████████████████████████████████████████████████████| 130182/130182 [00:09<00:00, 13489.10it/s]
# cell features:  (130182, 470)
#
# generating drug feats...
# 100%|███████████████████████████████████████████████████████████████████████| 130182/130182 [00:11<00:00, 10974.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 130182/130182 [00:11<00:00, 10972.39it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 130182/130182 [00:12<00:00, 10511.72it/s]
# drug features:  (130182, 1594)
# data loaded
# 0:	learn: 0.1587915	total: 201ms	remaining: 2m
# 3:	learn: 0.1534658	total: 1.03s	remaining: 2m 33s
# 6:	learn: 0.1494612	total: 1.69s	remaining: 2m 23s
# 9:	learn: 0.1466548	total: 2.36s	remaining: 2m 19s
# 12:	learn: 0.1446260	total: 3.05s	remaining: 2m 17s
# 15:	learn: 0.1432336	total: 3.69s	remaining: 2m 14s
# 18:	learn: 0.1421000	total: 4.33s	remaining: 2m 12s
# 21:	learn: 0.1410988	total: 5s	remaining: 2m 11s
# 24:	learn: 0.1401973	total: 5.69s	remaining: 2m 10s
# 27:	learn: 0.1395702	total: 6.36s	remaining: 2m 10s
# 30:	learn: 0.1388889	total: 7.07s	remaining: 2m 9s
# 33:	learn: 0.1384166	total: 7.78s	remaining: 2m 9s
# 36:	learn: 0.1378715	total: 8.44s	remaining: 2m 8s
# 39:	learn: 0.1373324	total: 9.09s	remaining: 2m 7s
# 42:	learn: 0.1369984	total: 9.76s	remaining: 2m 6s
# 45:	learn: 0.1366213	total: 10.4s	remaining: 2m 5s
# 48:	learn: 0.1363002	total: 11.1s	remaining: 2m 4s
# 51:	learn: 0.1360590	total: 11.7s	remaining: 2m 3s
# 54:	learn: 0.1356646	total: 12.4s	remaining: 2m 3s
# 57:	learn: 0.1352551	total: 13.1s	remaining: 2m 2s
# 60:	learn: 0.1350890	total: 13.8s	remaining: 2m 1s
# 63:	learn: 0.1348220	total: 14.4s	remaining: 2m
# 66:	learn: 0.1344816	total: 15.1s	remaining: 2m
# 69:	learn: 0.1342838	total: 15.8s	remaining: 1m 59s
# 72:	learn: 0.1339366	total: 16.5s	remaining: 1m 58s
# 75:	learn: 0.1336912	total: 17.2s	remaining: 1m 58s
# 78:	learn: 0.1332618	total: 18s	remaining: 1m 58s
# 81:	learn: 0.1329297	total: 18.7s	remaining: 1m 57s
# 84:	learn: 0.1325947	total: 19.4s	remaining: 1m 57s
# 87:	learn: 0.1323159	total: 20.1s	remaining: 1m 56s
# 90:	learn: 0.1320607	total: 20.8s	remaining: 1m 56s
# 93:	learn: 0.1318816	total: 21.4s	remaining: 1m 55s
# 96:	learn: 0.1317360	total: 22.1s	remaining: 1m 54s
# 99:	learn: 0.1314215	total: 22.8s	remaining: 1m 54s
# 102:	learn: 0.1311195	total: 23.5s	remaining: 1m 53s
# 105:	learn: 0.1309452	total: 24.1s	remaining: 1m 52s
# 108:	learn: 0.1305885	total: 24.8s	remaining: 1m 51s
# 111:	learn: 0.1302495	total: 25.5s	remaining: 1m 51s
# 114:	learn: 0.1299742	total: 26.2s	remaining: 1m 50s
# 117:	learn: 0.1296737	total: 26.9s	remaining: 1m 49s
# 120:	learn: 0.1294352	total: 27.5s	remaining: 1m 48s
# 123:	learn: 0.1291546	total: 28.1s	remaining: 1m 47s
# 126:	learn: 0.1288319	total: 28.8s	remaining: 1m 47s
# 129:	learn: 0.1285788	total: 29.4s	remaining: 1m 46s
# 132:	learn: 0.1284065	total: 30s	remaining: 1m 45s
# 135:	learn: 0.1280350	total: 30.7s	remaining: 1m 44s
# 138:	learn: 0.1276538	total: 31.4s	remaining: 1m 44s
# 141:	learn: 0.1272883	total: 32.1s	remaining: 1m 43s
# 144:	learn: 0.1269457	total: 32.8s	remaining: 1m 42s
# 147:	learn: 0.1266572	total: 33.4s	remaining: 1m 42s
# 150:	learn: 0.1264742	total: 34.2s	remaining: 1m 41s
# 153:	learn: 0.1260479	total: 34.9s	remaining: 1m 40s
# 156:	learn: 0.1258511	total: 35.5s	remaining: 1m 40s
# 159:	learn: 0.1257137	total: 36.1s	remaining: 1m 39s
# 162:	learn: 0.1253120	total: 36.8s	remaining: 1m 38s
# 165:	learn: 0.1251185	total: 37.5s	remaining: 1m 37s
# 168:	learn: 0.1247510	total: 38.2s	remaining: 1m 37s
# 171:	learn: 0.1243621	total: 38.9s	remaining: 1m 36s
# 174:	learn: 0.1241998	total: 39.6s	remaining: 1m 36s
# 177:	learn: 0.1238149	total: 40.3s	remaining: 1m 35s
# 180:	learn: 0.1236001	total: 41s	remaining: 1m 34s
# 183:	learn: 0.1233665	total: 41.7s	remaining: 1m 34s
# 186:	learn: 0.1231392	total: 42.3s	remaining: 1m 33s
# 189:	learn: 0.1229698	total: 42.9s	remaining: 1m 32s
# 192:	learn: 0.1228417	total: 43.5s	remaining: 1m 31s
# 195:	learn: 0.1225312	total: 44.2s	remaining: 1m 31s
# 198:	learn: 0.1223745	total: 44.8s	remaining: 1m 30s
# 201:	learn: 0.1221652	total: 45.5s	remaining: 1m 29s
# 204:	learn: 0.1218142	total: 46.2s	remaining: 1m 28s
# 207:	learn: 0.1214255	total: 46.9s	remaining: 1m 28s
# 210:	learn: 0.1211478	total: 47.6s	remaining: 1m 27s
# 213:	learn: 0.1210303	total: 48.2s	remaining: 1m 26s
# 216:	learn: 0.1207176	total: 48.9s	remaining: 1m 26s
# 219:	learn: 0.1204836	total: 49.5s	remaining: 1m 25s
# 222:	learn: 0.1202112	total: 50.2s	remaining: 1m 24s
# 225:	learn: 0.1199573	total: 50.9s	remaining: 1m 24s
# 228:	learn: 0.1198197	total: 51.6s	remaining: 1m 23s
# 231:	learn: 0.1195360	total: 52.4s	remaining: 1m 23s
# 234:	learn: 0.1192154	total: 53.2s	remaining: 1m 22s
# 237:	learn: 0.1190441	total: 54s	remaining: 1m 22s
# 240:	learn: 0.1188153	total: 54.7s	remaining: 1m 21s
# 243:	learn: 0.1186945	total: 55.5s	remaining: 1m 20s
# 246:	learn: 0.1186339	total: 56.1s	remaining: 1m 20s
# 249:	learn: 0.1184957	total: 56.7s	remaining: 1m 19s
# 252:	learn: 0.1182807	total: 57.3s	remaining: 1m 18s
# 255:	learn: 0.1181094	total: 58s	remaining: 1m 17s
# 258:	learn: 0.1180131	total: 58.6s	remaining: 1m 17s
# 261:	learn: 0.1178126	total: 59.2s	remaining: 1m 16s
# 264:	learn: 0.1177274	total: 59.9s	remaining: 1m 15s
# 267:	learn: 0.1175273	total: 1m	remaining: 1m 15s
# 270:	learn: 0.1173257	total: 1m 1s	remaining: 1m 14s
# 273:	learn: 0.1171727	total: 1m 1s	remaining: 1m 13s
# 276:	learn: 0.1170036	total: 1m 2s	remaining: 1m 13s
# 279:	learn: 0.1167282	total: 1m 3s	remaining: 1m 12s
# 282:	learn: 0.1164533	total: 1m 4s	remaining: 1m 11s
# 285:	learn: 0.1163799	total: 1m 4s	remaining: 1m 10s
# 288:	learn: 0.1162277	total: 1m 5s	remaining: 1m 10s
# 291:	learn: 0.1160656	total: 1m 5s	remaining: 1m 9s
# 294:	learn: 0.1158078	total: 1m 6s	remaining: 1m 8s
# 297:	learn: 0.1155816	total: 1m 7s	remaining: 1m 8s
# 300:	learn: 0.1153444	total: 1m 8s	remaining: 1m 7s
# 303:	learn: 0.1153171	total: 1m 8s	remaining: 1m 6s
# 306:	learn: 0.1151103	total: 1m 9s	remaining: 1m 6s
# 309:	learn: 0.1149614	total: 1m 10s	remaining: 1m 5s
# 312:	learn: 0.1148645	total: 1m 10s	remaining: 1m 4s
# 315:	learn: 0.1146219	total: 1m 11s	remaining: 1m 4s
# 318:	learn: 0.1143793	total: 1m 12s	remaining: 1m 3s
# 321:	learn: 0.1141350	total: 1m 12s	remaining: 1m 2s
# 324:	learn: 0.1140682	total: 1m 13s	remaining: 1m 2s
# 327:	learn: 0.1138362	total: 1m 14s	remaining: 1m 1s
# 330:	learn: 0.1136811	total: 1m 14s	remaining: 1m
# 333:	learn: 0.1135350	total: 1m 15s	remaining: 1m
# 336:	learn: 0.1133099	total: 1m 16s	remaining: 59.4s
# 339:	learn: 0.1131611	total: 1m 16s	remaining: 58.7s
# 342:	learn: 0.1130535	total: 1m 17s	remaining: 58s
# 345:	learn: 0.1128732	total: 1m 17s	remaining: 57.2s
# 348:	learn: 0.1127473	total: 1m 18s	remaining: 56.6s
# 351:	learn: 0.1125472	total: 1m 19s	remaining: 55.9s
# 354:	learn: 0.1123656	total: 1m 20s	remaining: 55.3s
# 357:	learn: 0.1121694	total: 1m 20s	remaining: 54.6s
# 360:	learn: 0.1120459	total: 1m 21s	remaining: 53.9s
# 363:	learn: 0.1118975	total: 1m 21s	remaining: 53.2s
# 366:	learn: 0.1117747	total: 1m 22s	remaining: 52.5s
# 369:	learn: 0.1115517	total: 1m 23s	remaining: 51.8s
# 372:	learn: 0.1113503	total: 1m 24s	remaining: 51.2s
# 375:	learn: 0.1112067	total: 1m 24s	remaining: 50.5s
# 378:	learn: 0.1110460	total: 1m 25s	remaining: 49.8s
# 381:	learn: 0.1108437	total: 1m 26s	remaining: 49.2s
# 384:	learn: 0.1106831	total: 1m 26s	remaining: 48.5s
# 387:	learn: 0.1106068	total: 1m 27s	remaining: 47.7s
# 390:	learn: 0.1105312	total: 1m 27s	remaining: 47s
# 393:	learn: 0.1103849	total: 1m 28s	remaining: 46.3s
# 396:	learn: 0.1102127	total: 1m 29s	remaining: 45.7s
# 399:	learn: 0.1100859	total: 1m 29s	remaining: 44.9s
# 402:	learn: 0.1100154	total: 1m 30s	remaining: 44.2s
# 405:	learn: 0.1098869	total: 1m 31s	remaining: 43.5s
# 408:	learn: 0.1096991	total: 1m 31s	remaining: 42.9s
# 411:	learn: 0.1095254	total: 1m 32s	remaining: 42.2s
# 414:	learn: 0.1094119	total: 1m 33s	remaining: 41.5s
# 417:	learn: 0.1092807	total: 1m 33s	remaining: 40.8s
# 420:	learn: 0.1091549	total: 1m 34s	remaining: 40.1s
# 423:	learn: 0.1090139	total: 1m 35s	remaining: 39.4s
# 426:	learn: 0.1088367	total: 1m 35s	remaining: 38.8s
# 429:	learn: 0.1087036	total: 1m 36s	remaining: 38.1s
# 432:	learn: 0.1085784	total: 1m 37s	remaining: 37.4s
# 435:	learn: 0.1084257	total: 1m 37s	remaining: 36.7s
# 438:	learn: 0.1082596	total: 1m 38s	remaining: 36.1s
# 441:	learn: 0.1080565	total: 1m 39s	remaining: 35.4s
# 444:	learn: 0.1079040	total: 1m 39s	remaining: 34.7s
# 447:	learn: 0.1077435	total: 1m 40s	remaining: 34.1s
# 450:	learn: 0.1075981	total: 1m 41s	remaining: 33.4s
# 453:	learn: 0.1073667	total: 1m 41s	remaining: 32.7s
# 456:	learn: 0.1072357	total: 1m 42s	remaining: 32.1s
# 459:	learn: 0.1070042	total: 1m 43s	remaining: 31.4s
# 462:	learn: 0.1068566	total: 1m 43s	remaining: 30.8s
# 465:	learn: 0.1066567	total: 1m 44s	remaining: 30.1s
# 468:	learn: 0.1065877	total: 1m 45s	remaining: 29.4s
# 471:	learn: 0.1064036	total: 1m 45s	remaining: 28.7s
# 474:	learn: 0.1062363	total: 1m 46s	remaining: 28s
# 477:	learn: 0.1061707	total: 1m 47s	remaining: 27.3s
# 480:	learn: 0.1059869	total: 1m 47s	remaining: 26.7s
# 483:	learn: 0.1059005	total: 1m 48s	remaining: 26s
# 486:	learn: 0.1057931	total: 1m 48s	remaining: 25.3s
# 489:	learn: 0.1055777	total: 1m 49s	remaining: 24.6s
# 492:	learn: 0.1054729	total: 1m 50s	remaining: 23.9s
# 495:	learn: 0.1053443	total: 1m 50s	remaining: 23.3s
# 498:	learn: 0.1051778	total: 1m 51s	remaining: 22.6s
# 501:	learn: 0.1050258	total: 1m 52s	remaining: 21.9s
# 504:	learn: 0.1048694	total: 1m 52s	remaining: 21.2s
# 507:	learn: 0.1047258	total: 1m 53s	remaining: 20.6s
# 510:	learn: 0.1045237	total: 1m 54s	remaining: 19.9s
# 513:	learn: 0.1043453	total: 1m 55s	remaining: 19.2s
# 516:	learn: 0.1042965	total: 1m 55s	remaining: 18.6s
# 519:	learn: 0.1042296	total: 1m 56s	remaining: 17.9s
# 522:	learn: 0.1040613	total: 1m 56s	remaining: 17.2s
# 525:	learn: 0.1038996	total: 1m 57s	remaining: 16.5s
# 528:	learn: 0.1037860	total: 1m 58s	remaining: 15.9s
# 531:	learn: 0.1036547	total: 1m 58s	remaining: 15.2s
# 534:	learn: 0.1034972	total: 1m 59s	remaining: 14.5s
# 537:	learn: 0.1034047	total: 2m	remaining: 13.8s
# 540:	learn: 0.1033134	total: 2m	remaining: 13.2s
# 543:	learn: 0.1031699	total: 2m 1s	remaining: 12.5s
# 546:	learn: 0.1030417	total: 2m 1s	remaining: 11.8s
# 549:	learn: 0.1028956	total: 2m 2s	remaining: 11.2s
# 552:	learn: 0.1028765	total: 2m 3s	remaining: 10.5s
# 555:	learn: 0.1027038	total: 2m 3s	remaining: 9.81s
# 558:	learn: 0.1024938	total: 2m 4s	remaining: 9.14s
# 561:	learn: 0.1023779	total: 2m 5s	remaining: 8.47s
# 564:	learn: 0.1022839	total: 2m 5s	remaining: 7.8s
# 567:	learn: 0.1021885	total: 2m 6s	remaining: 7.13s
# 570:	learn: 0.1020888	total: 2m 7s	remaining: 6.46s
# 573:	learn: 0.1019538	total: 2m 7s	remaining: 5.79s
# 576:	learn: 0.1017540	total: 2m 8s	remaining: 5.13s
# 579:	learn: 0.1016415	total: 2m 9s	remaining: 4.46s
# 582:	learn: 0.1016066	total: 2m 9s	remaining: 3.78s
# 585:	learn: 0.1014360	total: 2m 10s	remaining: 3.12s
# 588:	learn: 0.1013359	total: 2m 11s	remaining: 2.45s
# 591:	learn: 0.1012394	total: 2m 11s	remaining: 1.78s
# 594:	learn: 0.1011431	total: 2m 12s	remaining: 1.11s
# 597:	learn: 0.1010273	total: 2m 12s	remaining: 445ms
# 599:	learn: 0.1009614	total: 2m 13s	remaining: 0us
# training finished
